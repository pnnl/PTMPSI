# %%
from ptmpsi.alphafold import prediction
from ptmpsi.protein import Protein
from ptmpsi.nwchem import get_qm_data

# %%
snc = Protein()

# %%
snc.prepend(chain="A", residue="ASN")

# %%
snc.write_pdb('asn.pdb')

# %%
snc.modify("A:ASN1", "deamidation")
# Out:
# 	 Found rotamer with no clashes!

# %%
snc.write_pdb('asn_deamidation.pdb')

# %%
snc = Protein()

snc.prepend(chain="A", residue="GLN")
snc.write_pdb('gln.pdb')

snc.modify("A:GLN1", "deamidation")

snc.write_pdb('gln_deamidation.pdb')
# Out:
# 	 Found rotamer with no clashes!
